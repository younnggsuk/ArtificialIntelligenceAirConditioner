# %% [markdown]
# # 1. Simple CNN Model

# %%
import os

base_dir = os.getcwd()

# dataset paths
dataset_path = os.path.join(base_dir, 'datasets')
train_dir = os.path.join(dataset_path, 'train')
val_dir = os.path.join(dataset_path, 'val')

# 저장할 model path
save_dir = os.path.join(base_dir, 'saved_models')

classes = ['0_front', '1_back', '1_front', '2_back', '2_front', '5_front', 'ILU']

# train, validation의 각 class별 directory path
train_cls_dirs = [os.path.join(train_dir, c) for c in classes]
val_cls_dirs = [os.path.join(val_dir, c) for c in classes]

# %%
import cv2
import numpy as np

# Load dataset
def get_X_y_datas(class_dirs):
    X = []
    y = []
    for i, dir_path in enumerate(class_dirs):
        files = sorted(os.listdir(class_dirs[i]))
        files_paths = [os.path.join(dir_path, f) for f in files]
        
        for file_path in files_paths:
            img_bgr = cv2.imread(file_path, cv2.IMREAD_COLOR)
            img_rgb = cv2.cvtColor(img_bgr, cv2.COLOR_BGR2RGB)
            input_img = img_rgb.astype(np.float32)/255.
            
            X.append(input_img)
            y.append(int(i))
            
    return np.array(X), np.array(y).astype(np.uint8)

# %%
from tensorflow.keras.utils import to_categorical

num_classes = 7

# Load train, validation datas
X_train, y_train = get_X_y_datas(train_cls_dirs)
X_val, y_val = get_X_y_datas(val_cls_dirs)

# Shuffle
idx = np.random.permutation(len(X_train))
X_train, y_train = X_train[idx], y_train[idx]

idx = np.random.permutation(len(X_val))
X_val, y_val = X_val[idx], y_val[idx]

# one-hot encoding
y_train = to_categorical(y_train, num_classes)
y_val = to_categorical(y_val, num_classes)

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
# Out:
# (18654, 250, 200, 3) (18654, 7)
# (9222, 250, 200, 3) (9222, 7)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam, RMSprop

# 학습에 사용할 callback
callbacks_list = [
    EarlyStopping(
        monitor='val_loss',
        patience=20,
    ),
    ModelCheckpoint(
        filepath=os.path.join(save_dir, 'hand_sign_simple_cnn.h5'),
        monitor='val_loss',
        save_best_only=True,
    ),
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        verbose=1
    )
]

# %%
import tensorflow as tf

from tensorflow.keras import models, layers
from tensorflow.keras import regularizers

h = 250 # height
w = 200 # width
c = 3  # channels

# Multi GPU
strategy = tf.distribute.MirroredStrategy()
with strategy.scope():
    model = models.Sequential()

    model.add(layers.Conv2D(16, 3, input_shape=(h, w, c,)))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(32, 3))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(64, 3))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(128, 3))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.Conv2D(256, 3))
    model.add(layers.BatchNormalization())
    model.add(layers.ReLU())
    model.add(layers.MaxPooling2D((2, 2)))

    model.add(layers.GlobalAveragePooling2D())

    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))

    model.compile(optimizer=RMSprop(),
                  loss='categorical_crossentropy',
                  metrics=['acc'])

model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0', '/job:localhost/replica:0/task:0/device:GPU:1')
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 248, 198, 16)      448
# _________________________________________________________________
# batch_normalization (BatchNo (None, 248, 198, 16)      64
# _________________________________________________________________
# re_lu (ReLU)                 (None, 248, 198, 16)      0
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 124, 99, 16)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 122, 97, 32)       4640
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 122, 97, 32)       128
# _________________________________________________________________
# re_lu_1 (ReLU)               (None, 122, 97, 32)       0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 61, 48, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 59, 46, 64)        18496
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 59, 46, 64)        256
# _________________________________________________________________
# re_lu_2 (ReLU)               (None, 59, 46, 64)        0
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 29, 23, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 27, 21, 128)       73856
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 27, 21, 128)       512
# _________________________________________________________________
# re_lu_3 (ReLU)               (None, 27, 21, 128)       0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 13, 10, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 11, 8, 256)        295168
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 11, 8, 256)        1024
# _________________________________________________________________
# re_lu_4 (ReLU)               (None, 11, 8, 256)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 5, 4, 256)         0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 256)               0
# _________________________________________________________________
# dense (Dense)                (None, 128)               32896
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 428,391
# Trainable params: 427,399
# Non-trainable params: 992
# _________________________________________________________________

# %%
batch_size = 64
n_epochs = 100

history = model.fit(X_train, y_train,
                    epochs=n_epochs, batch_size=batch_size,
                    validation_data=(X_val, y_val),
                    callbacks=callbacks_list)
# Out:
# Train on 18654 samples, validate on 9222 samples
# Epoch 1/100
# INFO:tensorflow:batch_all_reduce: 24 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# INFO:tensorflow:batch_all_reduce: 24 all-reduces with algorithm = nccl, num_packs = 1, agg_small_grads_max_bytes = 0 and agg_small_grads_max_group = 10
# 18654/18654 [==============================] - 29s 2ms/sample - loss: 1.4428 - acc: 0.4497 - val_loss: 2.3275 - val_acc: 0.2555
# Epoch 2/100
# 18654/18654 [==============================] - 8s 453us/sample - loss: 0.5923 - acc: 0.8010 - val_loss: 0.8609 - val_acc: 0.7096
# Epoch 3/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.3021 - acc: 0.9023 - val_loss: 1.4292 - val_acc: 0.6242
# Epoch 4/100
# 18654/18654 [==============================] - 8s 444us/sample - loss: 0.1890 - acc: 0.9396 - val_loss: 0.3189 - val_acc: 0.8957
# Epoch 5/100
# 18654/18654 [==============================] - 8s 439us/sample - loss: 0.1307 - acc: 0.9557 - val_loss: 0.6034 - val_acc: 0.8107
# Epoch 6/100
# 18654/18654 [==============================] - 8s 442us/sample - loss: 0.0987 - acc: 0.9686 - val_loss: 0.4565 - val_acc: 0.8595
# Epoch 7/100
# 18654/18654 [==============================] - 8s 438us/sample - loss: 0.0755 - acc: 0.9759 - val_loss: 1.1945 - val_acc: 0.6818
# Epoch 8/100
# 18654/18654 [==============================] - 8s 441us/sample - loss: 0.0641 - acc: 0.9794 - val_loss: 0.6276 - val_acc: 0.8322
# Epoch 9/100
# 18496/18654 [============================>.] - ETA: 0s - loss: 0.0509 - acc: 0.9832
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 18654/18654 [==============================] - 8s 446us/sample - loss: 0.0514 - acc: 0.9831 - val_loss: 1.3950 - val_acc: 0.7049
# Epoch 10/100
# 18654/18654 [==============================] - 8s 444us/sample - loss: 0.0167 - acc: 0.9950 - val_loss: 0.1963 - val_acc: 0.9418
# Epoch 11/100
# 18654/18654 [==============================] - 8s 441us/sample - loss: 0.0147 - acc: 0.9959 - val_loss: 0.3166 - val_acc: 0.9192
# Epoch 12/100
# 18654/18654 [==============================] - 8s 444us/sample - loss: 0.0102 - acc: 0.9971 - val_loss: 0.1922 - val_acc: 0.9521
# Epoch 13/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.0093 - acc: 0.9971 - val_loss: 0.2004 - val_acc: 0.9469
# Epoch 14/100
# 18654/18654 [==============================] - 8s 449us/sample - loss: 0.0069 - acc: 0.9981 - val_loss: 0.3379 - val_acc: 0.9169
# Epoch 15/100
# 18654/18654 [==============================] - 8s 448us/sample - loss: 0.0074 - acc: 0.9981 - val_loss: 0.1958 - val_acc: 0.9481
# Epoch 16/100
# 18654/18654 [==============================] - 8s 444us/sample - loss: 0.0079 - acc: 0.9977 - val_loss: 0.1564 - val_acc: 0.9610
# Epoch 17/100
# 18654/18654 [==============================] - 8s 439us/sample - loss: 0.0081 - acc: 0.9974 - val_loss: 0.5681 - val_acc: 0.8766
# Epoch 18/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.0071 - acc: 0.9978 - val_loss: 0.3771 - val_acc: 0.9053
# Epoch 19/100
# 18654/18654 [==============================] - 8s 443us/sample - loss: 0.0064 - acc: 0.9982 - val_loss: 0.2581 - val_acc: 0.9339
# Epoch 20/100
# 18654/18654 [==============================] - 8s 442us/sample - loss: 0.0080 - acc: 0.9975 - val_loss: 0.1563 - val_acc: 0.9625
# Epoch 21/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.0068 - acc: 0.9983 - val_loss: 0.7138 - val_acc: 0.8789
# Epoch 22/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.0060 - acc: 0.9981 - val_loss: 0.4204 - val_acc: 0.9147
# Epoch 23/100
# 18654/18654 [==============================] - 8s 440us/sample - loss: 0.0053 - acc: 0.9982 - val_loss: 0.4299 - val_acc: 0.9027
# Epoch 24/100
# 18654/18654 [==============================] - 8s 445us/sample - loss: 0.0050 - acc: 0.9985 - val_loss: 0.2058 - val_acc: 0.9587
# Epoch 25/100
# 18624/18654 [============================>.] - ETA: 0s - loss: 0.0057 - acc: 0.9982
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 18654/18654 [==============================] - 8s 446us/sample - loss: 0.0057 - acc: 0.9981 - val_loss: 0.9781 - val_acc: 0.8312
# Epoch 26/100
# 18654/18654 [==============================] - 8s 451us/sample - loss: 0.0028 - acc: 0.9994 - val_loss: 0.1202 - val_acc: 0.9690
# Epoch 27/100
# 18654/18654 [==============================] - 8s 450us/sample - loss: 5.3669e-04 - acc: 0.9999 - val_loss: 0.1011 - val_acc: 0.9745
# Epoch 28/100
# 18654/18654 [==============================] - 8s 449us/sample - loss: 6.8385e-04 - acc: 0.9997 - val_loss: 0.0849 - val_acc: 0.9791
# Epoch 29/100
# 18654/18654 [==============================] - 8s 444us/sample - loss: 8.9162e-04 - acc: 0.9998 - val_loss: 0.1965 - val_acc: 0.9631
# Epoch 30/100
# 18654/18654 [==============================] - 8s 451us/sample - loss: 3.9798e-04 - acc: 0.9999 - val_loss: 0.1278 - val_acc: 0.9728
# Epoch 31/100
# 18654/18654 [==============================] - 8s 445us/sample - loss: 3.8663e-04 - acc: 0.9999 - val_loss: 0.1246 - val_acc: 0.9742
# Epoch 32/100
# 18654/18654 [==============================] - 8s 443us/sample - loss: 7.0321e-04 - acc: 0.9997 - val_loss: 0.0864 - val_acc: 0.9813
# Epoch 33/100
# 18496/18654 [============================>.] - ETA: 0s - loss: 6.2764e-04 - acc: 0.9998
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 18654/18654 [==============================] - 8s 449us/sample - loss: 6.2305e-04 - acc: 0.9998 - val_loss: 0.1083 - val_acc: 0.9779
# Epoch 34/100
# 18654/18654 [==============================] - 8s 447us/sample - loss: 3.2041e-04 - acc: 0.9999 - val_loss: 0.0930 - val_acc: 0.9822
# Epoch 35/100
# 18654/18654 [==============================] - 8s 453us/sample - loss: 1.6677e-04 - acc: 0.9999 - val_loss: 0.0766 - val_acc: 0.9832
# Epoch 36/100
# 18654/18654 [==============================] - 8s 448us/sample - loss: 7.0639e-05 - acc: 1.0000 - val_loss: 0.0963 - val_acc: 0.9808
# Epoch 37/100
# 18654/18654 [==============================] - 8s 449us/sample - loss: 6.9071e-05 - acc: 1.0000 - val_loss: 0.0931 - val_acc: 0.9816
# Epoch 38/100
# 18654/18654 [==============================] - 8s 447us/sample - loss: 3.8441e-05 - acc: 1.0000 - val_loss: 0.0835 - val_acc: 0.9819
# Epoch 39/100
# 18654/18654 [==============================] - 8s 443us/sample - loss: 9.8324e-05 - acc: 0.9999 - val_loss: 0.0817 - val_acc: 0.9833
# Epoch 40/100
# 18496/18654 [============================>.] - ETA: 0s - loss: 7.6399e-05 - acc: 1.0000
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 18654/18654 [==============================] - 8s 446us/sample - loss: 7.5770e-05 - acc: 1.0000 - val_loss: 0.0904 - val_acc: 0.9819
# Epoch 41/100
# 18654/18654 [==============================] - 8s 450us/sample - loss: 1.3756e-05 - acc: 1.0000 - val_loss: 0.0762 - val_acc: 0.9845
# Epoch 42/100
# 18654/18654 [==============================] - 8s 449us/sample - loss: 6.9508e-05 - acc: 0.9999 - val_loss: 0.0760 - val_acc: 0.9845
# Epoch 43/100
# 18654/18654 [==============================] - 8s 447us/sample - loss: 1.3151e-05 - acc: 1.0000 - val_loss: 0.0694 - val_acc: 0.9857
# Epoch 44/100
# 18654/18654 [==============================] - 8s 447us/sample - loss: 1.4394e-04 - acc: 0.9999 - val_loss: 0.0731 - val_acc: 0.9848
# Epoch 45/100
# 18654/18654 [==============================] - 8s 448us/sample - loss: 1.7799e-05 - acc: 1.0000 - val_loss: 0.0749 - val_acc: 0.9843
# Epoch 46/100
# 18654/18654 [==============================] - 8s 447us/sample - loss: 1.5723e-05 - acc: 1.0000 - val_loss: 0.0719 - val_acc: 0.9849
# Epoch 47/100
# 18654/18654 [==============================] - 8s 445us/sample - loss: 3.6608e-05 - acc: 1.0000 - val_loss: 0.0743 - val_acc: 0.9851
# Epoch 48/100
# 18560/18654 [============================>.] - ETA: 0s - loss: 6.1404e-06 - acc: 1.0000
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 18654/18654 [==============================] - 8s 445us/sample - loss: 6.1177e-06 - acc: 1.0000 - val_loss: 0.0755 - val_acc: 0.9837
# Epoch 49/100
# 18654/18654 [==============================] - 8s 448us/sample - loss: 4.1405e-06 - acc: 1.0000 - val_loss: 0.0706 - val_acc: 0.9856
# Epoch 50/100
# 18654/18654 [==============================] - 8s 446us/sample - loss: 7.5158e-06 - acc: 1.0000 - val_loss: 0.0740 - val_acc: 0.9853
# Epoch 51/100
# 18654/18654 [==============================] - 8s 450us/sample - loss: 5.8828e-06 - acc: 1.0000 - val_loss: 0.0756 - val_acc: 0.9851
# Epoch 52/100
# 18654/18654 [==============================] - 9s 458us/sample - loss: 1.5705e-05 - acc: 1.0000 - val_loss: 0.0729 - val_acc: 0.9850
# Epoch 53/100
# 18624/18654 [============================>.] - ETA: 0s - loss: 1.0183e-05 - acc: 1.0000
# Epoch 00053: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 18654/18654 [==============================] - 8s 445us/sample - loss: 1.0175e-05 - acc: 1.0000 - val_loss: 0.0741 - val_acc: 0.9857

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

# Plot accuracy curve
plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.figure()

# Plot loss curve
plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation_loss')
plt.title('Loss')
plt.legend()

plt.show()

# %%
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Plot confusion matrix
def confusion_matrix_plot(cm, classes, 
                          title='Normalized Confusion Matrix', 
                          normalize=True, 
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        cm = np.around(cm, decimals=2)
        cm[np.isnan(cm)] = 0.0
    plt.subplots(1, 1, figsize=(8, 8))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes)
    plt.yticks(tick_marks, classes)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    

y_preds = model.predict(X_val)
y_preds = np.argmax(y_preds, axis=1)
conf_mx = confusion_matrix(np.argmax(y_val, axis=1), y_preds)

confusion_matrix_plot(conf_mx, classes=classes)
