# %%
import os

base_dir = './datasets'

train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

train_0_front_dir = os.path.join(train_dir, '0_front')
train_1_back_dir = os.path.join(train_dir, '1_back')
train_1_front_dir = os.path.join(train_dir, '1_front')
train_2_back_dir = os.path.join(train_dir, '2_back')
train_2_front_dir = os.path.join(train_dir, '2_front')
train_5_front_dir = os.path.join(train_dir, '5_front')
train_ILU_dir = os.path.join(train_dir, 'ILU')

val_0_front_dir = os.path.join(val_dir, '0_front')
val_1_back_dir = os.path.join(val_dir, '1_back')
val_1_front_dir = os.path.join(val_dir, '1_front')
val_2_back_dir = os.path.join(val_dir, '2_back')
val_2_front_dir = os.path.join(val_dir, '2_front')
val_5_front_dir = os.path.join(val_dir, '5_front')
val_ILU_dir = os.path.join(val_dir, 'ILU')

save_dir = os.path.join(base_dir, 'saved_models')

# %%
import tensorflow as tf
from tensorflow.keras import models, layers

# batch_norm(batch_re-norm), ensemble, regularization 안했음

h = 150 # height
w = 150 # width
c = 3  # channels
num_classes = 7

model = models.Sequential()

model.add(layers.Conv2D(32, 3, activation='relu', input_shape=(h, w, c,)))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, 3, activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Conv2D(64, 3, activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))

# model.add(layers.Conv2D(128, 3, activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))

# model.add(layers.Conv2D(256, 3, activation='relu'))
# model.add(layers.MaxPooling2D((2, 2)))

model.add(layers.Flatten())

model.add(layers.Dense(64, activation='relu'))

model.add(layers.Dense(num_classes, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 32)      896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 74, 74, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 72, 72, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 36, 36, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 17, 17, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 18496)             0
# _________________________________________________________________
# dense (Dense)                (None, 64)                1183808
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 455
# =================================================================
# Total params: 1,240,583
# Trainable params: 1,240,583
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.4, 
                                   height_shift_range=0.4,
                                   shear_range=0.4,
                                   zoom_range=[1, 2],
                                   fill_mode='nearest')

val_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_dir,
                                                    target_size=(150, 150),
                                                    batch_size=25)

val_generator = val_datagen.flow_from_directory(val_dir,
                                                target_size=(150, 150),
                                                batch_size=25)
# Out:
# Found 1753 images belonging to 7 classes.
# Found 3500 images belonging to 7 classes.

# %%
import numpy as np

from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import RMSprop

callbacks_list = [
    EarlyStopping(
#         monitor='val_loss',
        monitor='val_acc',
        patience=10
    ),
    ModelCheckpoint(
        filepath=os.path.join(save_dir, 'hand_sign.h5'),
#         monitor='val_loss',
        monitor='val_acc',
        save_best_only=True
    ),
#     ReduceLROnPlateau(
#         # 검증 손실이 10 epoch동안 좋아지지 않으면 학습률에 0.1을 곱함(학습률을 1/10으로)
#         monitor='val_loss',
#         factor=0.1,
#         patience=10
#     )
]

model.compile(optimizer=RMSprop(),
              loss='categorical_crossentropy',
              metrics=['acc'])

steps_per_epoch = np.ceil(train_generator.samples/train_generator.batch_size)
validation_steps = np.ceil(val_generator.samples/val_generator.batch_size)

history = model.fit(train_generator, epochs=100,
                    steps_per_epoch=steps_per_epoch,
                    callbacks=callbacks_list,
                    validation_data=val_generator,
                    validation_steps=validation_steps)
# Out:
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# WARNING:tensorflow:sample_weight modes were coerced from
#   ...
#     to
#   ['...']
# Train for 71.0 steps, validate for 140.0 steps
# Epoch 1/100
# 71/71 [==============================] - 11s 153ms/step - loss: 2.0535 - acc: 0.1358 - val_loss: 1.9509 - val_acc: 0.1426
# Epoch 2/100
# 71/71 [==============================] - 10s 146ms/step - loss: 1.9526 - acc: 0.1477 - val_loss: 1.9458 - val_acc: 0.1451
# Epoch 3/100
# 71/71 [==============================] - 10s 146ms/step - loss: 1.9525 - acc: 0.1563 - val_loss: 1.9476 - val_acc: 0.1403
# Epoch 4/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.9478 - acc: 0.1318 - val_loss: 1.9457 - val_acc: 0.1511
# Epoch 5/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.9488 - acc: 0.1295 - val_loss: 1.9454 - val_acc: 0.1449
# Epoch 6/100
# 71/71 [==============================] - 10s 148ms/step - loss: 1.9478 - acc: 0.1529 - val_loss: 1.9462 - val_acc: 0.1431
# Epoch 7/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.9482 - acc: 0.1420 - val_loss: 1.9453 - val_acc: 0.1429
# Epoch 8/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.9432 - acc: 0.1563 - val_loss: 1.9491 - val_acc: 0.1680
# Epoch 9/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.9434 - acc: 0.1477 - val_loss: 1.9408 - val_acc: 0.1571
# Epoch 10/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.9336 - acc: 0.1677 - val_loss: 1.9376 - val_acc: 0.1754
# Epoch 11/100
# 71/71 [==============================] - 10s 147ms/step - loss: 1.9202 - acc: 0.1922 - val_loss: 1.9293 - val_acc: 0.1660
# Epoch 12/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.9282 - acc: 0.1700 - val_loss: 1.9234 - val_acc: 0.1734
# Epoch 13/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.9104 - acc: 0.1991 - val_loss: 1.8988 - val_acc: 0.2051
# Epoch 14/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.9022 - acc: 0.2037 - val_loss: 1.8705 - val_acc: 0.2483
# Epoch 15/100
# 71/71 [==============================] - 10s 147ms/step - loss: 1.8642 - acc: 0.2185 - val_loss: 1.8287 - val_acc: 0.2391
# Epoch 16/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.8403 - acc: 0.2333 - val_loss: 1.7808 - val_acc: 0.2774
# Epoch 17/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.7907 - acc: 0.2635 - val_loss: 1.7067 - val_acc: 0.2929
# Epoch 18/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.7115 - acc: 0.3006 - val_loss: 1.5820 - val_acc: 0.3363
# Epoch 19/100
# 71/71 [==============================] - 10s 148ms/step - loss: 1.6938 - acc: 0.3092 - val_loss: 1.5423 - val_acc: 0.3820
# Epoch 20/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.5993 - acc: 0.3508 - val_loss: 1.4571 - val_acc: 0.4009
# Epoch 21/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.5288 - acc: 0.3657 - val_loss: 1.3482 - val_acc: 0.4074
# Epoch 22/100
# 71/71 [==============================] - 11s 151ms/step - loss: 1.4984 - acc: 0.3714 - val_loss: 1.6077 - val_acc: 0.2891
# Epoch 23/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.4528 - acc: 0.3851 - val_loss: 1.2607 - val_acc: 0.4494
# Epoch 24/100
# 71/71 [==============================] - 11s 154ms/step - loss: 1.4115 - acc: 0.4096 - val_loss: 1.1836 - val_acc: 0.5023
# Epoch 25/100
# 71/71 [==============================] - 11s 151ms/step - loss: 1.3625 - acc: 0.4330 - val_loss: 1.2317 - val_acc: 0.4414
# Epoch 26/100
# 71/71 [==============================] - 10s 148ms/step - loss: 1.3502 - acc: 0.4450 - val_loss: 1.2232 - val_acc: 0.4257
# Epoch 27/100
# 71/71 [==============================] - 10s 146ms/step - loss: 1.2901 - acc: 0.4421 - val_loss: 1.2297 - val_acc: 0.4120
# Epoch 28/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.2881 - acc: 0.4455 - val_loss: 1.0493 - val_acc: 0.5374
# Epoch 29/100
# 71/71 [==============================] - 11s 151ms/step - loss: 1.2350 - acc: 0.4860 - val_loss: 1.1842 - val_acc: 0.5126
# Epoch 30/100
# 71/71 [==============================] - 11s 152ms/step - loss: 1.2229 - acc: 0.4678 - val_loss: 1.0957 - val_acc: 0.5137
# Epoch 31/100
# 71/71 [==============================] - 10s 148ms/step - loss: 1.2164 - acc: 0.4946 - val_loss: 1.4070 - val_acc: 0.4003
# Epoch 32/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.1581 - acc: 0.5048 - val_loss: 1.2191 - val_acc: 0.4794
# Epoch 33/100
# 71/71 [==============================] - 11s 153ms/step - loss: 1.1513 - acc: 0.5014 - val_loss: 0.8876 - val_acc: 0.5951
# Epoch 34/100
# 71/71 [==============================] - 11s 150ms/step - loss: 1.1144 - acc: 0.5225 - val_loss: 0.9158 - val_acc: 0.6126
# Epoch 35/100
# 71/71 [==============================] - 11s 148ms/step - loss: 1.1291 - acc: 0.5271 - val_loss: 0.8280 - val_acc: 0.6297
# Epoch 36/100
# 71/71 [==============================] - 11s 155ms/step - loss: 1.0861 - acc: 0.5454 - val_loss: 0.9696 - val_acc: 0.5691
# Epoch 37/100
# 71/71 [==============================] - 11s 152ms/step - loss: 1.0735 - acc: 0.5408 - val_loss: 0.8585 - val_acc: 0.6443
# Epoch 38/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.0230 - acc: 0.5710 - val_loss: 1.2107 - val_acc: 0.5214
# Epoch 39/100
# 71/71 [==============================] - 11s 152ms/step - loss: 1.0188 - acc: 0.5733 - val_loss: 0.7806 - val_acc: 0.6543
# Epoch 40/100
# 71/71 [==============================] - 11s 152ms/step - loss: 0.9870 - acc: 0.5859 - val_loss: 1.3557 - val_acc: 0.4546
# Epoch 41/100
# 71/71 [==============================] - 11s 149ms/step - loss: 1.0124 - acc: 0.5790 - val_loss: 0.8122 - val_acc: 0.6260
# Epoch 42/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.9769 - acc: 0.5950 - val_loss: 0.7608 - val_acc: 0.6560
# Epoch 43/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.9409 - acc: 0.6018 - val_loss: 0.8942 - val_acc: 0.6089
# Epoch 44/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.9232 - acc: 0.6098 - val_loss: 0.8554 - val_acc: 0.6266
# Epoch 45/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.9337 - acc: 0.6052 - val_loss: 0.9855 - val_acc: 0.5631
# Epoch 46/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.8869 - acc: 0.6469 - val_loss: 0.6562 - val_acc: 0.7157
# Epoch 47/100
# 71/71 [==============================] - 10s 146ms/step - loss: 0.8937 - acc: 0.6212 - val_loss: 1.1163 - val_acc: 0.5020
# Epoch 48/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.8616 - acc: 0.6566 - val_loss: 0.8889 - val_acc: 0.5846
# Epoch 49/100
# 71/71 [==============================] - 10s 146ms/step - loss: 0.8472 - acc: 0.6475 - val_loss: 0.8028 - val_acc: 0.6223
# Epoch 50/100
# 71/71 [==============================] - 10s 145ms/step - loss: 0.8371 - acc: 0.6492 - val_loss: 1.1378 - val_acc: 0.5197
# Epoch 51/100
# 71/71 [==============================] - 10s 148ms/step - loss: 0.8513 - acc: 0.6497 - val_loss: 0.9263 - val_acc: 0.6329
# Epoch 52/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.8129 - acc: 0.6543 - val_loss: 0.6802 - val_acc: 0.7334
# Epoch 53/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.8248 - acc: 0.6520 - val_loss: 0.7232 - val_acc: 0.6709
# Epoch 54/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.8160 - acc: 0.6549 - val_loss: 0.8209 - val_acc: 0.6486
# Epoch 55/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.7719 - acc: 0.6920 - val_loss: 0.7798 - val_acc: 0.6514
# Epoch 56/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.7377 - acc: 0.7045 - val_loss: 0.5651 - val_acc: 0.7643
# Epoch 57/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.7441 - acc: 0.6999 - val_loss: 0.6542 - val_acc: 0.7323
# Epoch 58/100
# 71/71 [==============================] - 11s 148ms/step - loss: 0.7460 - acc: 0.7034 - val_loss: 0.9257 - val_acc: 0.6103
# Epoch 59/100
# 71/71 [==============================] - 10s 146ms/step - loss: 0.7163 - acc: 0.7068 - val_loss: 0.8989 - val_acc: 0.6260
# Epoch 60/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.7070 - acc: 0.7096 - val_loss: 0.5607 - val_acc: 0.7840
# Epoch 61/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.6910 - acc: 0.7228 - val_loss: 0.6670 - val_acc: 0.7440
# Epoch 62/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.6664 - acc: 0.7239 - val_loss: 0.4243 - val_acc: 0.8300
# Epoch 63/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.6693 - acc: 0.7347 - val_loss: 0.5681 - val_acc: 0.7554
# Epoch 64/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.6540 - acc: 0.7399 - val_loss: 0.5102 - val_acc: 0.8054
# Epoch 65/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.6390 - acc: 0.7490 - val_loss: 0.5643 - val_acc: 0.7969
# Epoch 66/100
# 71/71 [==============================] - 10s 147ms/step - loss: 0.6180 - acc: 0.7553 - val_loss: 0.4403 - val_acc: 0.8157
# Epoch 67/100
# 71/71 [==============================] - 11s 148ms/step - loss: 0.6117 - acc: 0.7707 - val_loss: 0.4155 - val_acc: 0.8394
# Epoch 68/100
# 71/71 [==============================] - 11s 157ms/step - loss: 0.6241 - acc: 0.7678 - val_loss: 0.3982 - val_acc: 0.8560
# Epoch 69/100
# 71/71 [==============================] - 11s 155ms/step - loss: 0.5881 - acc: 0.7712 - val_loss: 0.5376 - val_acc: 0.7837
# Epoch 70/100
# 71/71 [==============================] - 11s 160ms/step - loss: 0.5932 - acc: 0.7712 - val_loss: 0.3727 - val_acc: 0.8637
# Epoch 71/100
# 71/71 [==============================] - 11s 152ms/step - loss: 0.6026 - acc: 0.7576 - val_loss: 0.3939 - val_acc: 0.8569
# Epoch 72/100
# 71/71 [==============================] - 11s 153ms/step - loss: 0.5386 - acc: 0.7969 - val_loss: 0.5365 - val_acc: 0.7786
# Epoch 73/100
# 71/71 [==============================] - 12s 162ms/step - loss: 0.5465 - acc: 0.7884 - val_loss: 0.3347 - val_acc: 0.8720
# Epoch 74/100
# 71/71 [==============================] - 11s 156ms/step - loss: 0.5591 - acc: 0.7861 - val_loss: 0.4358 - val_acc: 0.8297
# Epoch 75/100
# 71/71 [==============================] - 11s 155ms/step - loss: 0.5342 - acc: 0.8066 - val_loss: 0.4299 - val_acc: 0.8334
# Epoch 76/100
# 71/71 [==============================] - 11s 155ms/step - loss: 0.4979 - acc: 0.8186 - val_loss: 0.4278 - val_acc: 0.8294
# Epoch 77/100
# 71/71 [==============================] - 11s 159ms/step - loss: 0.5224 - acc: 0.8015 - val_loss: 0.5677 - val_acc: 0.7774
# Epoch 78/100
# 71/71 [==============================] - 12s 163ms/step - loss: 0.4952 - acc: 0.8163 - val_loss: 0.3311 - val_acc: 0.8869
# Epoch 79/100
# 71/71 [==============================] - 12s 162ms/step - loss: 0.4867 - acc: 0.8175 - val_loss: 0.4232 - val_acc: 0.8697
# Epoch 80/100
# 71/71 [==============================] - 12s 162ms/step - loss: 0.4830 - acc: 0.8175 - val_loss: 0.5426 - val_acc: 0.7763
# Epoch 81/100
# 71/71 [==============================] - 11s 153ms/step - loss: 0.4813 - acc: 0.8237 - val_loss: 0.6212 - val_acc: 0.7680
# Epoch 82/100
# 71/71 [==============================] - 11s 153ms/step - loss: 0.4556 - acc: 0.8277 - val_loss: 0.6415 - val_acc: 0.7854
# Epoch 83/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4938 - acc: 0.8260 - val_loss: 0.8482 - val_acc: 0.6749
# Epoch 84/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.4860 - acc: 0.8380 - val_loss: 0.3282 - val_acc: 0.8800
# Epoch 85/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4283 - acc: 0.8386 - val_loss: 0.9222 - val_acc: 0.6654
# Epoch 86/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.4685 - acc: 0.8397 - val_loss: 0.3451 - val_acc: 0.8737
# Epoch 87/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.4296 - acc: 0.8408 - val_loss: 0.2807 - val_acc: 0.9060
# Epoch 88/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4281 - acc: 0.8346 - val_loss: 0.2990 - val_acc: 0.8934
# Epoch 89/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.3895 - acc: 0.8483 - val_loss: 0.4454 - val_acc: 0.8503
# Epoch 90/100
# 71/71 [==============================] - 11s 149ms/step - loss: 0.4054 - acc: 0.8471 - val_loss: 0.3119 - val_acc: 0.8854
# Epoch 91/100
# 71/71 [==============================] - 11s 150ms/step - loss: 0.4157 - acc: 0.8534 - val_loss: 0.3526 - val_acc: 0.8677
# Epoch 92/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4083 - acc: 0.8465 - val_loss: 0.3384 - val_acc: 0.8646
# Epoch 93/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4132 - acc: 0.8511 - val_loss: 0.4392 - val_acc: 0.8263
# Epoch 94/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.4062 - acc: 0.8551 - val_loss: 0.2330 - val_acc: 0.9189
# Epoch 95/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.3829 - acc: 0.8637 - val_loss: 0.2129 - val_acc: 0.9269
# Epoch 96/100
# 71/71 [==============================] - 11s 156ms/step - loss: 0.3572 - acc: 0.8756 - val_loss: 0.3167 - val_acc: 0.8823
# Epoch 97/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.3802 - acc: 0.8591 - val_loss: 0.2555 - val_acc: 0.9157
# Epoch 98/100
# 71/71 [==============================] - 11s 152ms/step - loss: 0.3661 - acc: 0.8637 - val_loss: 0.2220 - val_acc: 0.9217
# Epoch 99/100
# 71/71 [==============================] - 11s 151ms/step - loss: 0.3762 - acc: 0.8654 - val_loss: 0.3167 - val_acc: 0.8826
# Epoch 100/100
# 71/71 [==============================] - 11s 152ms/step - loss: 0.3972 - acc: 0.8602 - val_loss: 0.2437 - val_acc: 0.9069

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation_loss')
plt.title('Loss')
plt.legend()

plt.show()

# # 그래프가 너무 지그재그면 하기
# def smooth_curve(points, factor=0.9):
#     smoothed_curve = []
#     for point in points:
#         if smoothed_curve:
#             prev = smoothed_curve[-1]
#             smoothed_curve.append(prev*factor + point*(1-factor))
#         else:
#             smoothed_curve.append(point)
            
#     return smoothed_curve

# plt.plot(epochs, smooth_curve(acc), 'b', label='smoothed train_acc')
# plt.plot(epochs, smooth_curve(val_acc), 'r', label='smoothed val_acc')
# plt.title("Accuracy")
# plt.legend()
# plt.figure()

# plt.plot(epochs, smooth_curve(loss), 'b', label='smoothed train_loss')
# plt.plot(epochs, smooth_curve(val_loss), 'r', label='smoothed val_loss')
# plt.title("Loss")
# plt.legend()
# plt.show()
